# %% [markdown]
# # IHOPE spatial proteomics figure generation
#
# ### This notebook does XYZ
#
# Move all figure-related functions to here except the follicle stuff.

# %% [markdown]
# ### Summaries of cell types: stacked barplots
#
# * All samples
# * Grouped by tissue type
# * Optional: with immune cells only or with all cells
# * Optional: remove unannotated cells or not

# %% [markdown]
# **All samples**
